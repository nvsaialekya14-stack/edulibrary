# %% [markdown]
# <a href="https://colab.research.google.com/github/nvsaialekya14-stack/edulibrary/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
plt.figure(figsize=(10,5))
plt.bar(bottom10['Item Name'], bottom10['Loss Rate (%)'])
plt.xticks(rotation=90)
plt.xlabel("Item Name")
plt.ylabel("Loss Rate (%)")
plt.title("Top 10 Items with Lowest Loss Rate")
plt.show()

# %%
bottom10 = df.sort_values(by='Loss Rate (%)').head(10)
bottom10
# Out:
#            Item Code                     Item Name  Loss Rate (%)
# 35   102900005116905            Green Hangjiao (1)            0.0
# 124  102900011029176                       Lameizi            0.0
# 126  102900011029299           Purple Screw Pepper            0.0
# 222  102900011036266  Velvet Antler Mushroom (Box)            0.0
# 218  102900011035849      Chinese Cabbage Seedling            0.0
# 242  106957634300010      The White Mushroom (Box)            0.0
# 234  106930274620090    Haixian Mushroom (Bag) (2)            0.0
# 228  102900051006229                Lotus Root Tip            0.0
# 172  102900011032480         Artemisia Stelleriana            0.0
# 168  102900011032282     Xiangtianhongcaitai (Bag)            0.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(top10['Item Name'], top10['Loss Rate (%)'])
plt.xticks(rotation=90)
plt.xlabel("Item Name")
plt.ylabel("Loss Rate (%)")
plt.title("Top 10 Items with Highest Loss Rate")
plt.show()

# %%
top10 = df.sort_values(by='Loss Rate (%)', ascending=False).head(10)
top10
# Out:
#            Item Code                       Item Name  Loss Rate (%)
# 43   102900005118824                  High Melon (1)          29.25
# 181  102900011033081                         Chuncai          29.03
# 67   102900011006689           Dongmenkou Xiaobaicai          27.84
# 68   102900011006948  Foreign Garland Chrysanthemum           26.16
# 59   102900011000632              Purple Cabbage (1)          25.53
# 226  102900051000944               Honghu Lotus Root          24.05
# 17   102900005115960                 Chinese Cabbage          22.27
# 55   102900011000175                         Kuaicai          20.38
# 140  102900011030608       The Steak Mushrooms (Box)          19.80
# 232  102900051010790                   Purple Beicai          19.58

# %%
df.isnull().sum()
# Out:
# Item Code        0
# Item Name        0
# Loss Rate (%)    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

top10 = df.sort_values(by='Loss Rate (%)', ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top10['Item Name'], top10['Loss Rate (%)'])
plt.xticks(rotation=90)
plt.title('Top 10 Items by Loss Rate')
plt.xlabel('Item Name')
plt.ylabel('Loss Rate (%)')
plt.show()

# %%
df.sort_values(by='Loss Rate (%)', ascending=False).head(10)
# Out:
#            Item Code                       Item Name  Loss Rate (%)
# 43   102900005118824                  High Melon (1)          29.25
# 181  102900011033081                         Chuncai          29.03
# 67   102900011006689           Dongmenkou Xiaobaicai          27.84
# 68   102900011006948  Foreign Garland Chrysanthemum           26.16
# 59   102900011000632              Purple Cabbage (1)          25.53
# 226  102900051000944               Honghu Lotus Root          24.05
# 17   102900005115960                 Chinese Cabbage          22.27
# 55   102900011000175                         Kuaicai          20.38
# 140  102900011030608       The Steak Mushrooms (Box)          19.80
# 232  102900051010790                   Purple Beicai          19.58

# %%
df.describe()
# Out:
#           Item Code  Loss Rate (%)
# count  2.510000e+02     251.000000
# mean   1.031908e+14       9.426693
# std    1.048400e+12       5.211027
# min    1.029000e+14       0.000000
# 25%    1.029000e+14       8.225000
# 50%    1.029000e+14       9.430000
# 75%    1.029000e+14      11.130000
# max    1.069740e+14      29.250000

# %%
df.isnull().sum()
# Out:
# Item Code        0
# Item Name        0
# Loss Rate (%)    0
# dtype: int64

# %%
df . info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Loss Rate (%)  251 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
import pandas as pd

df = pd.read_csv('/content/annex4.csv')

df.head()
# Out:
#          Item Code                 Item Name  Loss Rate (%)
# 0  102900005115168          Niushou Shengcai           4.39
# 1  102900005115199         Sichuan Red Cedar          10.46
# 2  102900005115250  Xixia Black Mushroom (1)          10.80
# 3  102900005115625     Local Xiaomao Cabbage           0.18
# 4  102900005115748              White Caitai           8.78
